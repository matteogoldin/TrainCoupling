# %%
import matplotlib.pyplot as plt 
import numpy as np
#Periodo 30 min

#Capacità semplice, timeLimit=300, runsNumber=10000 
capArray_5h = [7.1346, 9.9992, 11.9996, 12.0, 10.0, 11.7086, 7.0, 7.884299999999998, 0.0, 0.0]
N = list(range(1,len(capArray_5h)+1))

plt.plot(N, capArray_5h, "-o", color ='orange')
  
# naming of x-axis and y-axis
plt.xlabel('Num treni accoppiati')
plt.xticks(np.arange(1, len(N)+1, 1))
plt.ylabel('Capacità')
  
# naming the title of the plot
plt.title("Stima della capacità del tratto con train coupling in 5 ore")
  
plt.grid()

plt.savefig("capacities_5h.png", format="png", dpi=160)

plt.show()

# %%
#Capacità semplice, timeLimit=600, runsNumber=10000
capArray_10h = [15.850100000000001, 23.398999999999994, 29.940799999999996, 32.0, 30.0, 30.000000000000004, 28.0, 26.898600000000002, 26.486399999999996, 20.0]
N = list(range(1,len(capArray_10h)+1))

plt.plot(N, capArray_10h, "-o", color ='orange')
  
# naming of x-axis and y-axis
plt.xlabel('Num treni accoppiati')
plt.xticks(np.arange(1, len(N)+1, 1))
plt.ylabel('Capacità')
  
# naming the title of the plot
plt.title("Stima della capacità del tratto con train coupling in 10 ore")
  
plt.grid()

plt.savefig("capacities_10h.png", format="png", dpi=160)

plt.show()

# %%
#Capacità semplice, timeLimit=600, runsNumber=10000
capArray_15h = [24.3525, 36.34559999999998, 47.82510000000001, 52.0, 50.0, 48.0, 48.9753, 47.99999999999999, 45.0, 40.0]
N = list(range(1,len(capArray_15h)+1))

plt.plot(N, capArray_15h, "-o", color ='orange')
  
# naming of x-axis and y-axis
plt.xlabel('Num treni accoppiati')
plt.xticks(np.arange(1, len(N)+1, 1))
plt.ylabel('Capacità')
  
# naming the title of the plot
plt.title("Stima della capacità del tratto con train coupling in 15 ore")
  
plt.grid()

plt.savefig("capacities_15h.png", format="png", dpi=160)

plt.show()

# %%
#Capacità semplice
import pandas as pd
cap_table = {
    "5 ore": capArray_5h,
    "10 ore": capArray_10h,
    "15 ore": capArray_15h
} 

df = pd.DataFrame(cap_table)
df = df.reset_index(drop=True)
df.index = df.index + 1
#df.transpose().to_excel("cap_tab.xlsx")
df.to_excel("cap_tab.xlsx")
df
# Out:
#       5 ore   10 ore   15 ore
# 1    7.1346  15.8501  24.3525
# 2    9.9992  23.3990  36.3456
# 3   11.9996  29.9408  47.8251
# 4   12.0000  32.0000  52.0000
# 5   10.0000  30.0000  50.0000
# 6   11.7086  30.0000  48.0000
# 7    7.0000  28.0000  48.9753
# 8    7.8843  26.8986  48.0000
# 9    0.0000  26.4864  45.0000
# 10   0.0000  20.0000  40.0000
